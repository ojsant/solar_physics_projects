# %%
import multiplot as m
from multiplot import load_data, make_plot

# %%
# TODO plot range integration to main GUI
display(m.options.plot_range)

# %%
load_data()

# %%
fig, axs = make_plot()
# Out:
# Chosen plot range:
# 2022-03-14 00:00:00 - 2022-03-16 00:00:00
# Chosen channels:
# SEPT electrons: (3, 4, 5, 6, 7, 8), 6
# HET electrons: (0, 1, 2), 3
# SEPT protons: (2, 3, 4, 5), 4
# HET protons: (2, 3, 4, 5, 6), 5
# 2025-03-19 12:43:47 - sunpy - INFO: Obtained JPL HORIZONS location for STEREO-A (spacecraft) (-234)
# INFO: Obtained JPL HORIZONS location for STEREO-A (spacecraft) (-234)    [sunpy.coordinates.ephemeris]
# (<Figure size 2400x5400 with 11 Axes>,
#  array([<Axes: title={'center': 'STEREO A'}, ylabel='Frequency (MHz)'>,
#         <Axes: ylabel='Flux\n[(cm$^2$ sr s MeV)$^{-1}]$'>,
#         <Axes: ylabel='Flux\n[(cm$^2$ sr s MeV)$^{-1}]$'>,
#         <Axes: ylabel='B [nT]'>,
#         <Axes: ylabel='$\\Theta_\\mathrm{B}$ [°]'>,
#         <Axes: ylabel='$\\Phi_\\mathrm{B}$ [°]'>,
#         <Axes: ylabel='T$_\\mathrm{p}$ [K]'>,
#         <Axes: ylabel='N$_\\mathrm{p}$ [cm$^{-3}$]'>,
# ...
