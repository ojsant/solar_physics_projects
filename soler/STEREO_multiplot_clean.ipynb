# %% [markdown]
# ---
# # STEREO <a class="anchor" id="stereo-loader"></a>
#
# - GitHub: https://github.com/serpentine-h2020/SEPpy

# %%
# TODO: 

# av_en SEPT, HET

# other mag loader
# implement PAD plots, implement mag angles, polarity

# mag legend a bit wonky

# GUI

# %% [markdown]
# #### Importing

# %%
import stereo_tools
import datetime as dt
# Out:
# c:\Users\osant\Desktop\solar_physics_projects\soler\stereo_tools.py:278: SyntaxWarning: invalid escape sequence '\m'
#   axs[i].set_ylabel("N$_\mathrm{p}$ [cm$^{-3}$]", fontsize=font_ylabel)

# %% [markdown]
# #### Define some general options

# %%
opt = {}
#Timestamp position
opt["pos_timestamp"] = None
#Path to save plots
opt["file_path"] = None


year = 2024
opt["startdate"] = X1 = dt.datetime(year, 1, 14,10)
opt["enddate"] = X2 = dt.datetime(year, 1, 16, 8)

#year = 2024
#startdate = dt.datetime(year, 5, 13,0)
#enddate = dt.datetime(year, 5, 14, 12)

#year = 2023
#startdate = X1 = dt.datetime(year, 10, 3, 0)
#enddate = X2 = dt.datetime(year, 10, 4)

#startdate = X1 = dt.datetime(year, 1, 18, 12, 0)
#enddate = X2 = dt.datetime(year, 1, 19, 22)

opt["sc"] = 'A'
opt["plot_radio"] = True
opt["plot_electrons"] = True
opt["plot_protons"] = True
opt["plot_pad"] = False
opt["plot_mag_angles"] = True 
opt["plot_mag"] = True
opt["plot_Vsw"] = True
opt["plot_N"] = True
opt["plot_T"] = True
opt["plot_polarity"] = False 

opt["plot_het"] = True

opt["legends_inside"] = False

opt["resample"] = '20min'
opt["resample_mag"] = '1min'

#Choose every n:th channel
#het_e has only 3 channels, no choosing!
opt["n_sept_e"] = 2
opt["n_sept_p"] = 3
opt["n_het_p"] = 1

opt["sept_viewing"] = 'sun' #viewing_list[0]
opt["mag_coord"] = 'RTN'

# %% [markdown]
# #### Load data

# %%
data = stereo_tools.load_data(opt)
# Out:
# WARNING: SunpyUserWarning: No units provided for variable "MAGFLAGUC". Assigning dimensionless units. [sunpy.io._cdf]
# 2025-03-04 12:09:27 - sunpy - WARNING: SunpyUserWarning: No units provided for variable "MAGFLAGUC". Assigning dimensionless units.
# WARNING: SunpyUserWarning: astropy did not recognize units of "Na". Assigning dimensionless units. If you think this unit should not be dimensionless, please raise an issue at https://github.com/sunpy/sunpy/issues [sunpy.io._cdf]
# 2025-03-04 12:10:11 - sunpy - WARNING: SunpyUserWarning: astropy did not recognize units of "Na". Assigning dimensionless units. If you think this unit should not be dimensionless, please raise an issue at https://github.com/sunpy/sunpy/issues
# WARNING: SunpyUserWarning: astropy did not recognize units of "Na". Assigning dimensionless units. If you think this unit should not be dimensionless, please raise an issue at https://github.com/sunpy/sunpy/issues [sunpy.io._cdf]
# 2025-03-04 12:10:11 - sunpy - WARNING: SunpyUserWarning: astropy did not recognize units of "Na". Assigning dimensionless units. If you think this unit should not be dimensionless, please raise an issue at https://github.com/sunpy/sunpy/issues
# WARNING: SunpyUserWarning: astropy did not recognize units of "Na". Assigning dimensionless units. If you think this unit should not be dimensionless, please raise an issue at https://github.com/sunpy/sunpy/issues [sunpy.io._cdf]
# 2025-03-04 12:10:11 - sunpy - WARNING: SunpyUserWarning: astropy did not recognize units of "Na". Assigning dimensionless units. If you think this unit should not be dimensionless, please raise an issue at https://github.com/sunpy/sunpy/issues
# WARNING: SunpyUserWarning: astropy did not recognize units of "Na". Assigning dimensionless units. If you think this unit should not be dimensionless, please raise an issue at https://github.com/sunpy/sunpy/issues [sunpy.io._cdf]
# 2025-03-04 12:10:12 - sunpy - WARNING: SunpyUserWarning: astropy did not recognize units of "Na". Assigning dimensionless units. If you think this unit should not be dimensionless, please raise an issue at https://github.com/sunpy/sunpy/issues
# WARNING: SunpyUserWarning: astropy did not recognize units of "Na". Assigning dimensionless units. If you think this unit should not be dimensionless, please raise an issue at https://github.com/sunpy/sunpy/issues [sunpy.io._cdf]
# 2025-03-04 12:10:12 - sunpy - WARNING: SunpyUserWarning: astropy did not recognize units of "Na". Assigning dimensionless units. If you think this unit should not be dimensionless, please raise an issue at https://github.com/sunpy/sunpy/issues

# %%
stereo_tools.make_plot(data, opt)
# Out:
# Channels:
# sept_e: [np.int64(0), np.int64(2), np.int64(4), np.int64(6), np.int64(8), np.int64(10), np.int64(12), np.int64(14)] , 8
# het_e: [np.int64(0), np.int64(1), np.int64(2)] , 3
# sept_p: [np.int64(0), np.int64(3), np.int64(6), np.int64(9), np.int64(12), np.int64(15), np.int64(18), np.int64(21), np.int64(24), np.int64(27)] , 10
# het_p: [np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10)] , 11

# %%
if opt["plot_polarity"]:
    polarity_colorwheel()
